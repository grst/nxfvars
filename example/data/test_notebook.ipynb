# %%
import sys

# %%
sys.path.insert(0, 'nxfvars')

# %%
from nxfvars import nxf

# %%
nxf.input("bar", default="default bar")
# Out:
# 'default bar'

# %%
nxf.input("foo", default="/default/foo")
# Out:
# '/default/foo'

# %%
nxf.params("global_param", default="default global_param")
# Out:
# 'default global_param'

# %%
nxf.params("module_param", default="default module param")
# Out:
# 'default module param'

# %%
nxf.task("cpus", "16")
# Out:
# '16'

# %%
with open(nxf.input("foo")) as f:
    print("The content of 'foo' is ", "".join(f.readlines()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a5f81f53066b> in <module>
# ----> 1 with open(nxf.input("foo")) as f:
#       2     print("The content of 'foo' is ", "".join(f.readlines()))
#
# ~/projects/2020/nxfvars/nxfvars/nxf_var_handler.py in input(self, key, default)
#      33
#      34     def input(self, key, default=None):
# ---> 35         return self._get_var("input", key, default)
#      36
#      37     def params(self, key, default=None):
#
# ~/projects/2020/nxfvars/nxfvars/nxf_var_handler.py in _get_var(self, root_key, key, default)
#      23             if default is None:
#      24                 raise ValueError(
# ---> 25                     f"{self.envvar} is not set and no default value defined. "
#      26                     "For running outside nextflow, define a default. "
#      27                     "If running from nextflow, did you include `${nxfVars(task)}`?"
#
# ValueError: NXF_VARS is not set and no default value defined. For running outside nextflow, define a default. If running from nextflow, did you include `${nxfVars(task)}`?
